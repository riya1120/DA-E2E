# %%
import pandas as pd

# %%
customers = pd.read_csv("../data/raw/olist_customers_dataset.csv")
orders =pd.read_csv("../data/raw/olist_orders_dataset.csv")
geo=pd.read_csv("../data/raw/olist_geolocation_dataset.csv")
items =pd.read_csv("../data/raw/olist_order_items_dataset.csv")
payments =pd.read_csv("../data/raw/olist_order_payments_dataset.csv")
reviews =pd.read_csv("../data/raw/olist_order_reviews_dataset.csv")
products =pd.read_csv("../data/raw/olist_products_dataset.csv")
sellers=pd.read_csv("../data/raw/olist_sellers_dataset.csv")
category =pd.read_csv("../data/raw/product_category_name_translation.csv")

# %% [markdown]
# #### Customers Table

# %%
#Shape of Table
customers.shape
# Out:
# (99441, 5)

# %%
#shows stop five records
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
#overview of that table(dataframe)
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#Checking for null values
customers.isnull().sum().sort_values(ascending=False)
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#Checking for duplicate values
customers.duplicated().sum()

#Checking duplicates in col
customers["customer_id"].duplicated().sum()

#drop dupilcate in whole table if exists
# customers = customers.drop_duplicates()
# Out:
# 0

# %%
#Text Cleaning
#      riYa  -> str.strip() -> To remove space
# riYa -> str.lower() -> riya to make al small
customers["customer_city"] = customers["customer_city"].str.strip().str.lower()
customers["customer_state"] = customers["customer_state"].str.strip().str.upper()

# %% [markdown]
# #### Orders Table

# %%
#shape of table
orders.shape
# Out:
# (99441, 8)

# %%
#show top five column
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#overview of that table(dataframe)
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders.isnull().sum().sort_values(ascending=False)
# Out:
# order_delivered_customer_date    2965
# order_delivered_carrier_date     1783
# order_approved_at                 160
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_estimated_delivery_date       0
# dtype: int64

# %%
#Changing Datatype from object(string) to datetime
#we dont use inplace 
#we use table_name["col_name"]=pd.to_datetime(table["col_name"])
orders["order_purchase_timestamp"]=pd.to_datetime(orders["order_purchase_timestamp"])
orders["order_approved_at"]=pd.to_datetime(orders["order_approved_at"])
orders["order_delivered_carrier_date"]=pd.to_datetime(orders["order_delivered_carrier_date"])
orders["order_delivered_customer_date"]=pd.to_datetime(orders["order_delivered_customer_date"])
orders["order_estimated_delivery_date"]=pd.to_datetime(orders["order_estimated_delivery_date"])

# %%
#Checking for duplicate values
orders.duplicated().sum() #--> DF

#Checking duplicates in a col(not neccesary)
orders["order_id"].duplicated().sum()   # --> Series

#drop dupilcate in whole table
# orders = orders.drop_duplicates()
# Out:
# 0

# %%
#check date logic
#This checks if there any record exists for given condition
(orders["order_purchase_timestamp"] > orders["order_delivered_customer_date"]).sum()

#This shows what are those record that satisfies this cond
# orders[(orders["order_purchase_timestamp"] > orders["order_delivered_customer_date"])]
# Out:
# 0

# %%
#adding  delivery time in (days) col
orders["delivery_day"]=(
    orders["order_delivered_customer_date"]-orders["order_purchase_timestamp"]
).dt.days
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders["delivery_day"].describe()
# Out:
# count    96476.000000
# mean        12.094086
# std          9.551746
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        209.000000
# Name: delivery_day, dtype: float64

# %%
#Find out records that satisfies condition(orders["delivery_day"] > 90) to know how many order took more than 90 days so that 
# we could deduce if 209 days is valid delivery day or not
#.shape just tell no of rows and col
orders[orders["delivery_day"] > 90].shape
orders[orders["delivery_day"] > 90].shape
#orders["delivery_day"] > 90 -> give us true/false where condition is satisfied
#orders[order....] -> This give us whole row(poora data) where condition is true
(orders["delivery_day"] > 90).sum()
# Out:
# 76

# %%
#orders["delivery_day"].value_counts() -> Count no of times each value comes in the col
# .sort_index() -> it sort the result in asc order
# .tail(10) -> give last 10 records hence we could see those max records
orders["delivery_day"].value_counts().sort_index().tail(10)
# Out:
# delivery_day
# 182.0    1
# 186.0    1
# 187.0    2
# 188.0    1
# 189.0    1
# 191.0    1
# 194.0    3
# 195.0    1
# 208.0    1
# 209.0    1
# Name: count, dtype: int64

# %% [markdown]
# #### Items

# %%
#Shape of Table
items.shape
# Out:
# (112650, 7)

# %%
#shows stop five records
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
#overview of that table(dataframe)
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
#Checking for null values
items.isnull().sum().sort_values(ascending=False)
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
#Changing Datatype from object(string) to datetime
#we dont use inplace 
#we use table_name["col_name"]=pd.to_datetime(table["col_name"])
items["shipping_limit_date"]=pd.to_datetime(items["shipping_limit_date"])

# %%
#Checking for duplicate values
items.duplicated().sum()

#Checking duplicates in col(not necessary)
# items["order_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Products Table

# %%
products.shape
# Out:
# (32951, 9)

# %%
products.info()
#We are checking the info of products table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# we are checking if there are null values or not in product table
products.isnull().sum().sort_values(ascending=False)
# Out:
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# product_id                      0
# dtype: int64

# %%
products["product_category_name_english"] # give data of that col
products["product_category_name_english"].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product_category_name_english'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
products = products.merge(
    category,
    on="product_category_name",
    how="left"
)
products
#To add cell above click on the left and press A
#To add cell down click on the left and press B

# %%
# .drop() is used to delete coloumn from table
# products = products.drop(
#     columns=[
#         "product_category_name_english_x",
#         "product_category_name_english_y"
#     ])
# Will throw error if col are absent

# %%
products

# %% [markdown]
# #### Item Table

# %%
items.shape

# %%
items.info()

# %%
items.isnull().sum().sort_values(ascending=False)

# %%
items.head()

# %%
items["order_id"].duplicated().sum()

# %% [markdown]
# #### GeoLocation

# %%
geo.shape

# %%
geo.head()

# %%
geo.info()

# %%
geo.isnull().sum()

# %%
geo["geolocation_city"]=geo["geolocation_city"].str.strip().str.lower()
geo["geolocation_state"]=geo["geolocation_state"].str.strip().str.upper()

# %%
geo.head()

# %%
customers.to_csv("../data/cleaned/customers_clean.csv", index=False)
orders.to_csv("../data/cleaned/orders_clean.csv", index=False)
geo.to_csv("../data/cleaned/geo_clean.csv", index=False)
items.to_csv("../data/cleaned/order_items_clean.csv", index=False)
payments.to_csv("../data/cleaned/payments_clean.csv", index=False)
reviews.to_csv("../data/cleaned/reviews_clean.csv", index=False)
products.to_csv("../data/cleaned/products_clean.csv", index=False)
sellers.to_csv("../data/cleaned/sellers_clean.csv", index=False)
# category.to_csv("../data/cleaned/product_category_name_translation.csv", index=False) # Not using this because hmnealready use kr rkha h ise join ke lie

# %%
customers.info()
orders.info()
geo.info()
items.info()
payments.info()
reviews.info()
products.info()
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
# ...

# %%
#Changing string to date time 
reviews["review_creation_date"]=pd.to_datetime(reviews["review_creation_date"])
reviews["review_answer_timestamp"]=pd.to_datetime(reviews["review_answer_timestamp"])
reviews.to_csv("../data/cleaned/reviews_clean.csv", index=False)
